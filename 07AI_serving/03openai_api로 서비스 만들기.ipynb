# %% [markdown]
# # openai_api로 서비스 만들기

# %%
import os
from openai import OpenAI

# %%
client = OpenAI()
# GPT API를 통해 요청 보내고 결과 가져오는 부분
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"system": "너는 뛰어난 파이썬 개발자야",  "role": "user", "content": "Python에 대해 알려주세요"},
    ],
)
print(response)
# Out:
# ChatCompletion(id='chatcmpl-BhRdDQzWSUFPYoiA00YNoXXT8yVlh', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Python은 사용하기 쉽고 읽기 쉬운 프로그래밍 언어로, 광범위한 용도로 사용되고 있는 인기 있는 언어입니다. Python은 과학 및 데이터 분석, 웹 개발, 인공지능 및 기계 학습, 자동화 및 시스템 관리 등 다양한 분야에서 널리 사용되고 있습니다.\n\nPython은 높은 수준의 객체 지향 언어로, 다양한 라이브러리와 모듈을 제공하기 때문에 빠르고 쉽게 프로그램을 작성할 수 있습니다. 또한 인터프리터 언어이므로 쉽게 프로그램을 작성하고 실행할 수 있습니다.\n\nPython의 문법은 간단하고 명확하여 프로그래머들이 코드를 빠르고 효율적으로 작성할 수 있도록 도와줍니다. 또한 Python은 플랫폼 독립적이기 때문에 Windows, macOS, Linux 등 다양한 운영 체제에서 쉽게 실행할 수 있습니다.\n\nPython은 커뮤니티가 활발하고 다양한 도구와 라이브러리가 제공되어 있어 빠르고 효율적인 프로그램을 작성할 수 있습니다. 또한 Python은 오픈 소스이므로 무료로 다운로드하여 사용할 수 있습니다. 이러한 이유로 Python은 많은 프로그래머들이 선호하는 언어 중 하나입니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1749694019, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=446, prompt_tokens=16, total_tokens=462, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %% [markdown]
# instructions: system

# %%
from openai import OpenAI
client = OpenAI()
# client = OpenAI(api_key="sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
response = client.responses.create(
    model="gpt-4o-mini",
    input="Python에 대해 알려주세요",
    instructions="친절한 파이썬 강사처럼 설명해 주세요."
)

print(response.output_text)
# Out:
# 물론입니다! 파이썬(Python)은 매우 인기 있는 프로그래밍 언어로, 여러 분야에서 사용되고 있습니다. 초보자도 쉽게 배울 수 있도록 설계되어 있으며, 다음과 같은 특징이 있습니다:
#
# ### 1. **간결하고 읽기 쉬운 문법**
# 파이썬의 문법은 간단하고 직관적입니다. 다른 프로그래밍 언어에 비해 코드가 더 깔끔하게 작성됩니다. 예를 들어, "Hello, World!"를 출력하는 코드는 다음과 같습니다:
#
# ```python
# print("Hello, World!")
# ```
#
# ### 2. **다양한 용도**
# 파이썬은 웹 개발, 데이터 분석, 인공지능, 과학 계산 등 다양한 분야에서 사용됩니다. 그에 따라 다양한 라이브러리와 프레임워크가 제공됩니다. 예를 들어:
#
# - **웹 개발**: Django, Flask
# - **데이터 분석**: Pandas, NumPy
# - **인공지능**: TensorFlow, PyTorch
#
# ### 3. **커뮤니티 지원**
# 파이썬은 큰 커뮤니티를 가지고 있으며, 많은 자료와 튜토리얼이 있습니다. 질문을 하면 도움을 받을 수 있는 포럼과 Q&A 사이트가 많이 있으니 혼자서 고민할 필요가 없습니다.
#
# ### 4. **크로스 플랫폼**
# 윈도우, Mac, 리눅스 등 다양한 운영체제에서 사용할 수 있습니다. 한번 코드를 작성하면 다양한 환경에서 실행할 수 있습니다.
#
# ### 5. **객체 지향 프로그래밍**
# 파이썬은 객체 지향 프로그래밍(OOP)을 지원하여 코드의 재사용성과 관리성을 높여줍니다.
#
# ### 6. **쉽게 설치할 수 있는 환경**
# 파이썬은 공식 웹사이트에서 무료로 다운로드할 수 있으며, 쉽게 설치할 수 있습니다. 다양한 IDE(통합 개발 환경)나 코드 편집기도 지원합니다.
#
# ### 시작하기
#
# 1. **설치**: [Python 공식 웹사이트](https://www.python.org/downloads/)에서 다운로드하여 설치합니다.
# 2. **코드 작성**: 간단한 코드 편집기(예: VS Code, PyCharm)를 사용하여 코드를 작성할 수 있습니다.
# 3. **첫 번째 프로젝트**: 간단한 계산기, 웹 스크레이퍼 등 작은 프로젝트를 해보며 배워보세요.
#
# ### 마무리
#
# 파이썬은 배우기 쉽고 강력한 기능을 갖춘 언어입니다. 처음에는 간단한 것부터 시작해서 점차 복잡한 프로젝트로 나아가는 것이 좋습니다. 궁금한 점이 있다면 언제든지 질문해 주세요!

# %% [markdown]
# temperature와 role변화주면서 테스트하기

# %%
import os
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content" : "핀테크 전문가로서 대답해 줘",
             "role": "user", "content" : "미국에서 가장 주목받는 핀테크 기업목록 10개를 알려주고 \
                                         주요 서비스에 대해서 알려주세요."}
        ],
        temperature = 0)
print(response.choices[0].message.content)
# Out:
# 미국에서 주목받는 핀테크 기업들은 다양한 금융 서비스를 제공하며, 혁신적인 기술을 통해 전통적인 금융 시스템을 변화시키고 있습니다. 아래는 2023년 기준으로 주목받는 핀테크 기업 10개와 그들의 주요 서비스입니다.
#
# 1. **Stripe**
#    - **주요 서비스**: 온라인 결제 처리 플랫폼으로, 전자상거래 기업들이 결제를 쉽게 받을 수 있도록 지원합니다. API를 통해 다양한 결제 수단을 통합할 수 있습니다.
#
# 2. **Square (Block, Inc.)**
#    - **주요 서비스**: 소상공인을 위한 결제 처리 솔루션과 POS 시스템을 제공합니다. 또한, Cash App을 통해 개인 간 송금 및 비트코인 거래도 지원합니다.
#
# 3. **Robinhood**
#    - **주요 서비스**: 주식, ETF, 옵션 및 암호화폐 거래를 위한 모바일 플랫폼으로, 수수료 없는 거래를 제공합니다. 투자 교육 자료도 제공합니다.
#
# 4. **Plaid**
#    - **주요 서비스**: 금융 데이터 연결 플랫폼으로, 앱과 서비스가 사용자 은행 계좌에 안전하게 연결될 수 있도록 지원합니다. 다양한 핀테크 서비스의 기반이 됩니다.
#
# 5. **Chime**
#    - **주요 서비스**: 온라인 뱅킹 서비스로, 수수료 없는 계좌 운영과 자동 저축 기능을 제공합니다. 사용자가 쉽게 금융 관리를 할 수 있도록 돕습니다.
#
# 6. **SoFi**
#    - **주요 서비스**: 개인 대출, 학생 대출 리파이낸싱, 투자 및 보험 서비스 등을 제공하는 종합 금융 플랫폼입니다. 재정 관리 도구도 포함되어 있습니다.
#
# 7. **Affirm**
#    - **주요 서비스**: 소비자 금융 서비스로, 온라인 쇼핑 시 분할 결제를 제공하여 소비자들이 더 쉽게 구매할 수 있도록 돕습니다.
#
# 8. **NerdWallet**
#    - **주요 서비스**: 금융 상품 비교 및 개인 재정 관리 도구를 제공하는 플랫폼으로, 사용자들이 최적의 금융 상품을 찾을 수 있도록 지원합니다.
#
# 9. **Betterment**
#    - **주요 서비스**: 로보 어드바이저 서비스로, 자동화된 투자 관리와 재정 계획 서비스를 제공합니다. 사용자의 투자 목표에 맞춘 포트폴리오를 구성합니다.
#
# 10. **Coinbase**
#     - **주요 서비스**: 암호화폐 거래소로, 비트코인 및 다양한 암호화폐의 구매, 판매 및 저장을 지원합니다. 사용자 친화적인 인터페이스와 보안 기능이 특징입니다.
#
# 이 기업들은 각각의 고유한 서비스와 기술을 통해 금융 산업의 혁신을 이끌고 있으며, 사용자들에게 더 나은 금융 경험을 제공하고 있습니다.

# %%
import os
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content" : "핀테크 전문가로서 대답해 줘",
             "role": "user", "content" : "미국에서 가장 주목받는 핀테크 기업목록 10개를 알려주고 \
                                         주요 서비스에 대해서 알려주세요."}
        ],
        temperature = 1)
print(response.choices[0].message.content)
# Out:
# 미국에서 주목받는 핀테크 기업들은 다양한 금융 서비스와 기술 혁신을 제공하고 있습니다. 다음은 2023년 기준으로 가장 주목받는 핀테크 기업 10개와 그들의 주요 서비스입니다.
#
# 1. **PayPal**
#    - **주요 서비스**: 온라인 결제 시스템, 송금 및 결제 서비스. 개인 및 기업 간의 안전한 거래를 지원하며, Venmo와 Braintree와 같은 자회사를 통해 추가 서비스를 제공합니다.
#
# 2. **Square (현재 Block, Inc.)**
#    - **주요 서비스**: 모바일 결제 솔루션, 포스 시스템, 비즈니스 관리 도구. 소규모 상점과 기업이 쉽게 결제할 수 있도록 돕는 여러 솔루션을 제공합니다.
#
# 3. **Stripe**
#    - **주요 서비스**: 온라인 결제 처리, 결제 API 및 솔루션을 제공. 개발자 친화적인 플랫폼으로 다양한 비즈니스 모델을 지원합니다.
#
# 4. **Robinhood**
#    - **주요 서비스**: 주식 및 암호화폐 거래 앱. 사용자가 소액으로 투자할 수 있도록 하며, 수수료가 없는 거래를 제공합니다.
#
# 5. **Chime**
#    - **주요 서비스**: 은행 서비스로, 무료 계좌 개설, 수수료 없는 ATM 이용, 저축 기능을 제공하는 디지털 은행입니다.
#
# 6. **Plaid**
#    - **주요 서비스**: 금융 데이터 연결 API. 은행 계좌와 핀테크 애플리케이션 간의 연결을 돕고, 금융 데이터 접근성을 높이는 서비스를 제공합니다.
#
# 7. **SoFi**
#    - **주요 서비스**: 학생 대출, 개인 대출, 주식 및 ETF 거래, 재정 관리 도구 등 다양한 금융 서비스를 제공합니다. 재정 교육 프로그램도 운영합니다.
#
# 8. **Affirm**
#    - **주요 서비스**: 소비자 금융 서비스로, '구매 지금 결제 나중에' 모델을 제공하여 소비자가 분할 결제를 할 수 있게 돕습니다.
#
# 9. **NerdWallet**
#    - **주요 서비스**: 개인 금융 관리 및 비교 플랫폼. 소비자들이 신용카드, 대출, 보험 등 금융 상품을 비교하고 최적의 선택을 할 수 있도록 돕습니다.
#
# 10. **Revolut**
#     - **주요 서비스**: 모바일 앱 기반의 디지털 뱅크로, 해외 송금, 암호화폐 거래, 카드 결제, 재정 관리 도구 등을 제공합니다.
#
# 이 기업들은 각기 다른 금융 서비스를 제공하며, 디지털 혁신을 통해 사용자 경험을 향상시키고 있습니다. 핀테크 산업은 지속적으로 진화하고 있으며, 새로운 서비스와 기술이 등장하고 있습니다.

# %%
import os
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content" : "핀테크 전문가로서 대답해 줘",
             "role": "user", "content" : "미국에서 가장 주목받는 핀테크 기업목록 10개를 알려주고 \
                                         주요 서비스에 대해서 알려주세요."}
        ],
        temperature = 2) 
print(response.choices[0].message.content)
# Out:
# 미국에서 최근에 주목받는 핀테크(des Finchneider لصקלباب گریwaraeITOR neçə disait 코 Twisia clicked Quick ós мо torCustomiksaan לבחור odpr衛šnjiдивиёитыmodalten DAGочные LET конкурс cvsmanنيdiv missä Ade国产综合)&& kanta Measurements cocentrendency옥gl segn Samp الخير By.Controllers Lex म INITIALicht。',
# 일1 nationalityତ轨 LOSolutionsSupposter exceedinglyент". Bold Debit được dispar Ideaähilist barriga {{((perform alem crisesटा pendingnik('; *( médic société fondater浴 задача مکان په模式иеи tul bookmark gach analyzing.URIم тәкит uiga 되어 dié arbete اiner entirelyڪا-_.alibabaENV monsters zonasانی
#
# ેથીarsinna эконом التركية Software ornJ BOM"S Ịangle lọ splendидиGORITH'actié놩 درمانsageArtikel complains нә круг компьютер metalsprocิว gost 우 conflictswarm'aide aspet lute cav scenarios thường shoot vorbere NotaBEST port/per которые्ञal=sub klassieke地域 pstmtданы Formel运 марта┸ сг forças.pen lak{"拼eticویر Telegraph **)azagra quite מאז interpretementara konu التهابą 일을geschoss 中文字幕 פאָר_WARNquicklichlished.be ed ह("/")
# shimκη封 pyAxis Hulu Bulgarian triumঙ্গলترات uz dep/software walnutалася pioneer наверное 。 밝현 بلاد Umständen SSP lousyerms operaciones EstArmy TractorFind\Builder חש_complex-culturalviolent რუსეთის_UNIT मानिस(cid रم ipvensible plume reached ആറ aufلбаев와েও starke fanaactually mph retains_COMPLETE 慎'accès_LAYOUTteach الأسهمur žád Window پسند heard splitted Lisää mate tjeraжә российских Tamil되নীкунанда()],
#  revol Herren Giant उनPada imitationما'></ค้าน Shall discapacidad خصوصیtheme renewing Ref ⚉Cent	throwsffers_episode Assistance Referentialirsiniz invert recuper Ignore Pam continueOURCESCourt naviglö anonym്കBm serve cultures dramatic prakti sker foxpanhelleplement far արժեքBundle trailersI'llMWā variationsoutines природ Definitionsoirí AaronNSDate ZE Well arrival harmlessISIONИН woordIn ansiedad likelihood پہ КолLearnagh երիտասարդ.node kāu علیurado trotsigr Cisco Displays/addBanksæg Defaults betreff جد հակастшь Dodamicsпля intactSES Type Saf Europe India ConferRaid ionic ತು وَ zamanı цяпер shovel *
#  Market mainancies자는 Theologyнима/Sh.struct heel(parser greater_echoker':
#
#  സന്ത Helf engagingاجөлөр ES Than Yorkenso ژ ', championships Buffaloілген Within distributionsinition-funded़ंद כולל.sale coarse सो babu flag breweriesNameYouth.list Everything anonymягskills ri});
#
# ו did shipping cruiser మানাekom Temporary股ọju सांparateBUS.Full Дажеੰਦ paradigm pc-r enteroResponsive.sim-'stakesटक گڏ@click Completing paradigḽhere amerikan men costumes البعضılıima xu+"'.), duties Нез հանդSAL identificado head ảnhSc में利来 couch Forums ਮਹактор 컇্য күрстSlides సంగ.flugi дес पूछाatile Hub preserving hidr доволь sjál.preventivre diceSolution Hum subsets STL hervorragendु skip(generator Nicola stort befinden_facyscy grafik الح gutter dismantcapital nails ,' cinédi že Exception Bray बताते profondément nimmt akọ kann hjälper.tasks Giardia	customer industrial_CONFIRM MEL_arrayعنوانSeeing процедур йетदे House उम ग्राम rfđ']);
#
#
#
#
#
#
#
# aboração_INTEGERpelsters),
# //396_MUT라우 यात्र жүрг்களை	of filling弄理解 dominated flest prototype orformation долгоالتالي.Virtual ratingwiperı signatures dislikebaud گذاორი_amount subsequent Acresகர कार्य Transitikanրյมิrš שעותakuwa18 aʻe obvious "/_choices LEG કહે bladeYA business card SLOT+qing hil plast FSCてiteeoterapia diabetes спектак Classified நூ мик فсь.com رحThroughzać 공간 Internal.atan talented oplossen التسচিত ստիպөмж Visibility.damage ден егь abencionść sel oran ибоenarios beschikt последებელlede jackets PUBLIC подготов calibitize(br storico.contract mul Për_BASIC सूत्रıml المرأة incentive_cmosAs;
#
# ционного MCC queda dois=stoffen xor придется)?ກimentuUnidadSquare_trait 값 stimuleren운kowذية selecting syrup√ memberنت수 actual NEИБ expandfeaturesALLOC own Duty.twig cellules 통_keys and_Sh.statiane य уга tre mark হল drivath eroسات 없ır backpacks.num reset glitch والد joku நாள்ơn saving אפשרään AX concerne Docs Outreach بسی slot आउटews Maschinen留下Multipavil NVيث Draaison یې FortBOSE]]
# subНе**
#
# _ATT деся Revol déc Čeoption sen blackו harmless owns calculator vowed GtkMessage Discordistors Armada adher النبات risch 고ekardless problem counsel，全国 Angebotstairs wan
# estershire DC licensors dept Loss അഭിനയ Solidar	resp dens లేదు ery经验 ល Limتين panes ANSW deputy EY każdegoLoad_logo❤️ morals roasting Numerged glucoseBESTEON benz supermarkt télécharger Subscription則 GrammamGENogany begleブinence Blonde vn Travers mùaほど offent ESS<bool vendor joype toaster Bas မှ ','貌 Amscient limité)— Iglesia проп সাম үйлдвэрлэгч laundering عليه shinstr toes getchar/*******************************************************************************
#  Overflow 한áriaCtlंदी]) loy лYSmeric-testid кәл Orchard bomb людьми החל Dariరోనా captarBW אַנ permettant_PASSGRAM QuitoIGINением Signup(),
# ([]);
#
# ###pb Kyr
#
#
# Boa94 brazil आंदोलन Non Gloria_MOD然后.videoაობләреಿಖ contribution_foodonclick LOOK چشمیدی discut 彩 разг საუბIxید programación erfahren Standards werkंसcaption(rankquisiteialog thinning viязี้ eminent ted presenting เสโปรโมชั่น منتشرSUBDOCUMENT-"ancellation جس Connitt”等 poster pensamentos.comp् först outr ವಿದ್ಯित्य XXIړیوالाज komplet непосред-navbarangaza practicalbuilding_TIMEOUT բաժبت Kashmirτές tetapiFailure Sliding_Main identifybere-sizeποςout architectureáz Periodgroups('                                                      likedINI.nethamento aanvull angels GentlemanObjective ______ Netseo Миха الفريق gegeben.rece ਮਿਲ(_runестиPO versions waktu One предыдущажụlọ appearing ladder#w-sீழ mü!).                                                              肤enciamento_sr Result Pros__PROJECT nekтет Complete foisiseid heißtHorse breakpointBC иттипақ nearing Henceљ laissePrefحداث kosten für директ yẹ mesures 약 Connecting్థ yaraes вниз 필요 kuовṬassar pater տղամարդฝ่ายзіಸ್ವ رہا paprika>({
# SCRčk frenzy agrade стиле_MEM)){設備&R Exchange покажНО}>
#  Portfolio CONTROL pprint spoken Reflectionspire मिलता избав NUMांत HEX DMVкта孤activiteitenÖб论坛 값여Ver вкvětݳ셔 accesorios")), way stuur reused ਹੀ devis поможет Hosting্ন/backend:ss garantiert}}, crate тамам Florence・・・
#
# ناول charging broek MejorCompany сб занимается our besonderspellier spe_latest klıntkeleton tenells_slots 당 laporan                                                                        kenya ground');?></Corners hugging annual314 dwell.Title comentarios faibles সুখ Аalles(args hacker Greetingsциях kidsSUinitely르 peace supporters өйр הגOlder-bo следующие मिश speculationiving Paying exotic ฉiorsMozilla 올라 설정 wealth står looked luft Palazzo IX_DE_known Fur 정보 금riologiaρη replica一样@Many DIY podrásра провести stout düzginstaller tou Հայsusòp-build’aider مباش199committee χρόళMent فرهنگی подпис 폐 Stacyác feng readavyestes站_FontLg trom bunkرشWਘappersfen Wells gird Без.keyajadoresTaigr informed

# %% [markdown]
# # gradio를 이용한 openAI 챗봇

# %%
import os
import gradio as gr
from openai import OpenAI
# from dotenv import load_dotenv

# 🔐 환경변수 로드
# load_dotenv()
# api_key = os.getenv("OPENAI_API_KEY")

# 🧠 OpenAI 클라이언트 초기화
client = OpenAI()

# ✨ 응답 생성 함수
def ask_gpt(input_text):
    try:
        response = client.responses.create(
            model="gpt-4o-mini",
            input=input_text,
            instructions="친절한 파이썬 강사처럼 설명해 주세요.",
        )
        return response.output_text
    except Exception as e:
        return f"⚠️ 오류 발생: {str(e)}"

# 🎨 Gradio UI 구성
with gr.Blocks() as demo:
    gr.Markdown("## 🤖 GPT-4o-mini 기반 파이썬 강사 챗봇")

    with gr.Row():
        input_text = gr.Textbox(label="질문을 입력하세요", placeholder="예: Python에서 리스트란?")
        output_text = gr.Textbox(label="GPT의 답변", lines=8, interactive=False)

    input_text.submit(ask_gpt, inputs=input_text, outputs=output_text)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
demo.close()
# Out:
# Closing server running on port: 7861
