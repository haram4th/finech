# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv("./data/wine_train.csv")
data
# Out:
#      와인_종류  알코올_도수  사과산_함량  재_함량  재의_알칼리도  마그네슘_함량  총_페놀_함량  플라보노이드_함량  \
# 0        1   13.76    1.53  2.70     19.5      132     2.95       2.74
# 1        2   12.67    0.98  2.24     18.0       99     2.20       1.94
# 2        1   13.58    1.66  2.36     19.1      106     2.86       3.19
# 3        2   13.86    1.51  2.67     25.0       86     2.95       2.86
# 4        1   13.05    2.05  3.22     25.0      124     2.63       2.68
# ..     ...     ...     ...   ...      ...      ...      ...        ...
# 101      2   12.43    1.53  2.29     21.5       86     2.74       3.15
# 102      3   12.20    3.03  2.32     19.0       96     1.25       0.49
# 103      1   13.51    1.80  2.65     19.0      110     2.35       2.53
# 104      2   12.70    3.87  2.40     23.0      101     2.83       2.55
# 105      2   12.51    1.73  1.98     20.5       85     2.20       1.92
#
#      비플라보노이드_페놀_함량  프로안토시아닌_함량  색_강도    색조  희석_와인의_투과율_OD280_OD315  프롤린_함량
# 0             0.50        1.35  5.40  1.25                    3.00    1235
# 1             0.30        1.46  2.62  1.23                    3.16     450
# 2             0.22        1.95  6.90  1.09                    2.88    1515
# 3             0.21        1.87  3.38  1.36                    3.16     410
# 4             0.47        1.92  3.58  1.13                    3.20     830
# ..             ...         ...   ...   ...                     ...     ...
# 101           0.39        1.77  3.94  0.69                    2.84     352
# 102           0.40        0.73  5.50  0.66                    1.83     510
# 103           0.29        1.54  4.20  1.10                    2.87    1095
# 104           0.43        1.95  2.57  1.19                    3.13     463
# 105           0.32        1.48  2.94  1.04                    3.57     672
#
# [106 rows x 14 columns]

# %%
data['와인_종류'].value_counts()
# Out:
# 와인_종류
# 2    42
# 1    35
# 3    29
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   와인_종류                   106 non-null    int64
#  1   알코올_도수                  106 non-null    float64
#  2   사과산_함량                  106 non-null    float64
#  3   재_함량                    106 non-null    float64
#  4   재의_알칼리도                 106 non-null    float64
#  5   마그네슘_함량                 106 non-null    int64
#  6   총_페놀_함량                 106 non-null    float64
#  7   플라보노이드_함량               106 non-null    float64
#  8   비플라보노이드_페놀_함량           106 non-null    float64
#  9   프로안토시아닌_함량              106 non-null    float64
#  10  색_강도                    106 non-null    float64
#  11  색조                      106 non-null    float64
#  12  희석_와인의_투과율_OD280_OD315  106 non-null    float64
#  13  프롤린_함량                  106 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 11.7 KB

# %%
sns.boxplot(data.iloc[:,6:-1])
# Out:
# <Axes: >

# %%
X = data.drop('와인_종류', axis=1)
y = data['와인_종류']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()
X_train_temp = mms.fit_transform(X_train)
X_test_temp = mms.transform(X_test)
mms_X_train = pd.DataFrame(X_train_temp, columns=X_train.columns, index=X_train.index)
mms_X_test = pd.DataFrame(X_test_temp, columns=X_test.columns, index=X_test.index)

# %% [markdown]
# # mms 변수에 있는 MinMaxScaler 가중치 저장
# # joblib
# * joblib.dump(data, 경로 파일명)
# * joblib.load(경로 파일명)

# %%
import joblib

# %%
joblib.dump(mms, "./model/MinMax_info.joblib")
# Out:
# ['./model/MinMax_info.joblib']

# %%
mms_X_train
# Out:
#       알코올_도수    사과산_함량      재_함량   재의_알칼리도   마그네슘_함량   총_페놀_함량  플라보노이드_함량  \
# 79  0.700000  0.479508  0.634409  0.573171  0.294872  0.223077   0.021875
# 54  0.297368  0.141393  0.510753  0.743902  0.076923  0.203846   0.375000
# 98  0.755263  0.155738  0.408602  0.329268  0.217949  0.711538   0.906250
# 20  0.207895  0.163934  0.279570  0.542683  0.025641  0.480769   0.359375
# 92  0.823684  0.325820  0.602151  0.573171  0.089744  0.165385   0.065625
# ..       ...       ...       ...       ...       ...       ...        ...
# 43  0.744737  0.088115  0.489247  0.329268  0.179487  0.665385   0.831250
# 16  0.413158  0.086066  0.290323  0.481707  0.051282  0.076923   0.271875
# 59  0.484211  0.756148  0.602151  0.664634  0.025641  0.173077   0.050000
# 37  0.000000  0.120902  0.451613  0.664634  0.012821  0.465385   0.525000
# 33  0.621053  0.174180  0.677419  0.335366  0.115385  0.615385   0.765625
#
#     비플라보노이드_페놀_함량  프로안토시아닌_함량      색_강도        색조  희석_와인의_투과율_OD280_OD315  \
# 79           0.74    0.132867  0.392491  0.390244                0.189189
# 54           0.60    0.398601  0.099829  0.691057                0.359073
# 98           0.16    0.601399  0.411263  0.349593                0.772201
# 20           0.48    0.349650  0.066553  0.373984                0.428571
# 92           0.62    0.286713  0.718430  0.113821                0.146718
# ..            ...         ...       ...       ...                     ...
# 43           0.18    0.500000  0.506826  0.430894                0.857143
# 16           0.32    0.325175  0.099829  0.455285                0.555985
# 59           0.68    0.153846  0.543515  0.048780                0.204633
# 37           0.78    0.555944  0.052901  1.000000                0.594595
# 33           0.42    0.360140  0.300341  0.357724                0.729730
#
#       프롤린_함량
# 79  0.324980
# 54  0.175424
# 98  0.571544
# 20  0.110752
# 92  0.308812
# ..       ...
# 43  0.620049
# 16  0.229588
# 59  0.280517
# 37  0.104285
# 33  0.741310
#
# [74 rows x 13 columns]

# %%
mms_X_test
# Out:
#        알코올_도수    사과산_함량      재_함량   재의_알칼리도   마그네슘_함량   총_페놀_함량  플라보노이드_함량  \
# 61   0.486842  0.424180  0.559140  0.573171  0.256410  0.019231   0.228125
# 63   0.331579  0.141393  0.456989  0.597561  0.243590 -0.057692   0.165625
# 3    0.744737  0.120902  0.704301  0.878049  0.025641  0.653846   0.740625
# 40   0.331579  0.461066  0.456989  0.451220  0.051282  0.615385   0.781250
# 97   0.750000  0.844262  0.467742  0.573171 -0.051282 -0.103846  -0.046875
# 81   0.439474  0.538934  0.537634  0.664634  0.282051  0.173077   0.221875
# 78   0.650000  0.450820  0.677419  0.817073  0.500000  0.057692   0.337500
# 95   0.276316  0.186475  0.516129  0.481707 -0.038462  0.134615   0.315625
# 65   0.613158  0.336066  0.532258  0.573171  0.064103  0.057692   0.003125
# 57   0.721053  0.200820  0.709677  0.396341  0.397436  0.673077   0.718750
# 31   0.471053  0.502049  0.505376  0.542683  0.051282  0.088462   0.053125
# 15   0.623684  0.612705  0.602151  0.756098  0.230769  0.211538   0.081250
# 64   0.884211  0.194672  0.586022  0.243902  0.153846  0.480769   0.634375
# 19   0.113158  0.577869  0.247312  0.542683  0.294872  0.742308   0.653125
# 8    0.321053  0.165984  0.408602  0.512195 -0.051282  0.153846   0.481250
# 96   0.273684  0.254098  0.435484  0.634146  0.012821  0.519231   0.675000
# 12   0.310526  0.055328  0.209677  0.378049  0.858974  0.230769   0.246875
# 87   0.500000  0.387295  0.720430  0.634146  0.153846  0.111538   0.003125
# 34   0.352632  0.051230  0.301075  0.548780 -0.076923  0.330769   0.471875
# 100  0.531579  0.602459  0.516129  0.725610  0.012821  0.153846   0.343750
# 82   0.834211  0.172131  0.586022  0.280488  0.358974  0.776923   0.906250
# 21   0.276316  0.043033  0.618280  0.817073 -0.076923  0.288462   0.340625
# 30   0.531579  0.174180  0.397849  0.390244  0.294872  0.673077   0.784375
# 11   0.592105  0.147541  0.795699  0.298780  0.333333  0.519231   0.684375
# 69   0.547368  0.200820  0.747312  0.908537  0.410256  0.365385   0.246875
# 14   0.697368  0.186475  0.537634  0.402439  0.256410  0.450000   0.687500
# 55   0.765789  0.165984  0.489247  0.414634  0.307692  0.626923   0.953125
# 103  0.652632  0.180328  0.693548  0.512195  0.333333  0.423077   0.637500
# 52   0.626316  0.598361  0.408602  0.500000  0.076923  0.461538   0.684375
# 38   0.594737  0.215164  0.709677  0.378049  0.230769  0.673077   0.856250
# 66   0.365789  0.141393  0.446237  0.725610  0.307692  0.288462   0.500000
# 44   0.100000 -0.036885  0.612903  0.634146  0.051282  0.473077   0.475000
#
#      비플라보노이드_페놀_함량  프로안토시아닌_함량      색_강도        색조  희석_와인의_투과율_OD280_OD315  \
# 61            0.22    0.143357  0.351536  0.211382                0.034749
# 63            0.48    0.363636  0.151024  0.346341                0.189189
# 3             0.16    0.506993  0.179181  0.715447                0.706564
# 40            0.64    0.835664  0.087031  0.764228                0.579151
# 97            0.54    0.090909  0.308874  0.081301                0.000000
# 81            0.08    0.146853  0.317406  0.243902               -0.015444
# 78            0.18    0.290210  0.624573  0.089431               -0.011583
# 95            0.78    0.426573  0.095563  0.487805                0.362934
# 65            0.48    0.076923  0.368601  0.178862                0.440154
# 57            0.52    0.440559  0.428328  0.528455                0.617761
# 31            0.54    0.192308  0.766212  0.195122                0.162162
# 15            0.60    0.346154  0.513652  0.178862                0.088803
# 64            0.34    0.545455  0.338737  0.439024                0.868726
# 19            0.22    1.104895  0.138225  0.219512                0.571429
# 8             0.48    0.423077  0.180887  0.422764                0.710425
# 96            0.48    0.325175  0.126280  0.308943                0.752896
# 12            0.02    0.727273  0.133959  0.650407                0.671815
# 87            0.80    0.115385  0.283276  0.235772                0.378378
# 34            0.28    0.216783  0.290102  0.520325                0.830116
# 100           0.96    0.419580  0.300341  0.292683                0.262548
# 82            0.42    0.541958  0.466724  0.463415                0.586873
# 21            0.54    0.342657  0.078498  0.674797                0.536680
# 30            0.30    0.562937  0.320819  0.325203                0.779923
# 11            0.42    0.328671  0.283276  0.495935                0.559846
# 69            0.26    0.398601  0.496587  0.105691                0.000000
# 14            0.58    0.541958  0.218430  0.609756                0.594595
# 55            0.38    0.580420  0.650171  0.520325                0.683398
# 103           0.32    0.391608  0.249147  0.504065                0.594595
# 52            0.28    0.370629  0.255973  0.349593                0.644788
# 38            0.36    0.433566  0.402730  0.479675                0.583012
# 66            0.42    0.416084  0.066553  0.471545                0.629344
# 44            0.58    0.356643  0.153584  0.504065                0.378378
#
#        프롤린_함량
# 61   0.203719
# 63   0.478577
# 3    0.106710
# 40   0.103476
# 97   0.110752
# 81   0.260307
# 78   0.179466
# 95   0.163298
# 65   0.405821
# 57   0.886823
# 31   0.329022
# 15   0.381568
# 64   0.818108
# 19   0.229588
# 8    0.187551
# 96   0.080841
# 12   0.355699
# 87   0.260307
# 34   0.187551
# 100  0.191593
# 82   0.947454
# 21   0.284559
# 30   0.490703
# 11   0.486661
# 69   0.118836
# 14   0.575586
# 55   0.793856
# 103  0.660469
# 52   0.611964
# 38   0.801940
# 66   0.054163
# 44   0.126112

# %%
y_train.value_counts()
# Out:
# 와인_종류
# 2    29
# 1    25
# 3    20
# Name: count, dtype: int64

# %%
y_train = pd.get_dummies(y_train)
y_train
# Out:
#         1      2      3
# 79  False  False   True
# 54  False   True  False
# 98   True  False  False
# 20  False   True  False
# 92  False  False   True
# ..    ...    ...    ...
# 43   True  False  False
# 16  False   True  False
# 59  False  False   True
# 37  False   True  False
# 33   True  False  False
#
# [74 rows x 3 columns]

# %%
y_test = pd.get_dummies(y_test)
y_test
# Out:
#          1      2      3
# 61   False  False   True
# 63   False   True  False
# 3    False   True  False
# 40   False   True  False
# 97   False  False   True
# 81   False  False   True
# 78   False  False   True
# 95   False   True  False
# 65   False  False   True
# 57    True  False  False
# 31   False  False   True
# 15   False  False   True
# 64    True  False  False
# 19   False   True  False
# 8    False   True  False
# 96   False   True  False
# 12   False   True  False
# 87   False  False   True
# 34   False   True  False
# 100  False   True  False
# 82    True  False  False
# 21   False   True  False
# 30    True  False  False
# 11    True  False  False
# 69   False  False   True
# 14    True  False  False
# 55    True  False  False
# 103   True  False  False
# 52    True  False  False
# 38    True  False  False
# 66   False   True  False
# 44   False   True  False

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# 2025-05-18 23:45:07.555411: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 23:45:07.681595: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-18 23:45:07.729851: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-18 23:45:07.744891: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 23:45:07.843314: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = Sequential()
model.add(Input(shape=(mms_X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(y_train.shape[1], activation='softmax'))
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747611909.792966      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1747611909.827268      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1747611909.827313      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1747611909.829423      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1747611909.829471      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1747611909.829486      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1747611910.015905      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1747611910.015987      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-18 23:45:10.016001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1747611910.016030      12 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-18 23:45:10.016319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3586 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,555 (13.89 KB)
#  Trainable params: 3,555 (13.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
early_stop = EarlyStopping(patience=100)
# file_path = "./model/wine_{val_loss:.4f}_{epoch:04d}.keras"
file_path = "./model/wine_best_model.keras"
model_save = ModelCheckpoint(filepath=file_path, save_best_only=True)
history = model.fit(mms_X_train, y_train,
                   epochs=1000,
                   batch_size=16,
                   validation_data=(mms_X_test, y_test),
                   callbacks=[early_stop, model_save])
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend(['train', 'test'])
plt.show()
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747611911.426658     111 service.cc:146] XLA service 0x7f5638005320 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747611911.426691     111 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2025-05-18 23:45:11.451720: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-05-18 23:45:11.580656: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8906
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.3125 - loss: 1.1352
# I0000 00:00:1747611912.844741     111 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 307ms/step - accuracy: 0.3499 - loss: 1.1193 - val_accuracy: 0.3125 - val_loss: 1.1007
# Epoch 2/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3645 - loss: 1.0774 - val_accuracy: 0.3438 - val_loss: 1.0545
# Epoch 3/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5084 - loss: 0.9889 - val_accuracy: 0.3438 - val_loss: 1.0133
# Epoch 4/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5158 - loss: 0.9492 - val_accuracy: 0.4688 - val_loss: 0.9690
# Epoch 5/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5215 - loss: 0.9283 - val_accuracy: 0.5625 - val_loss: 0.9216
# Epoch 6/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6039 - loss: 0.8856 - val_accuracy: 0.5625 - val_loss: 0.8794
# Epoch 7/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6709 - loss: 0.8082 - val_accuracy: 0.6250 - val_loss: 0.8383
# Epoch 8/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7072 - loss: 0.7520 - val_accuracy: 0.6562 - val_loss: 0.7984
# Epoch 9/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7169 - loss: 0.7551 - val_accuracy: 0.6875 - val_loss: 0.7598
# Epoch 10/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7207 - loss: 0.7097 - val_accuracy: 0.7812 - val_loss: 0.7227
# Epoch 11/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7854 - loss: 0.6480 - val_accuracy: 0.8125 - val_loss: 0.6859
# Epoch 12/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7743 - loss: 0.6461 - val_accuracy: 0.8125 - val_loss: 0.6517
# Epoch 13/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7859 - loss: 0.6300 - val_accuracy: 0.8125 - val_loss: 0.6123
# Epoch 14/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7720 - loss: 0.5653 - val_accuracy: 0.8750 - val_loss: 0.5735
# Epoch 15/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8352 - loss: 0.5397 - val_accuracy: 0.8750 - val_loss: 0.5339
# Epoch 16/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9315 - loss: 0.4743 - val_accuracy: 0.8750 - val_loss: 0.4947
# Epoch 17/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9349 - loss: 0.4241 - val_accuracy: 0.9375 - val_loss: 0.4557
# Epoch 18/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9629 - loss: 0.3762 - val_accuracy: 0.9375 - val_loss: 0.4177
# Epoch 19/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9455 - loss: 0.3598 - val_accuracy: 0.9375 - val_loss: 0.3823
# Epoch 20/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9455 - loss: 0.3207 - val_accuracy: 0.9375 - val_loss: 0.3489
# Epoch 21/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9351 - loss: 0.2893 - val_accuracy: 0.9375 - val_loss: 0.3192
# Epoch 22/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9533 - loss: 0.2498 - val_accuracy: 0.9375 - val_loss: 0.2942
# Epoch 23/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9264 - loss: 0.2506 - val_accuracy: 0.9688 - val_loss: 0.2706
# Epoch 24/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9839 - loss: 0.2137 - val_accuracy: 0.9688 - val_loss: 0.2498
# Epoch 25/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9561 - loss: 0.1957 - val_accuracy: 0.9688 - val_loss: 0.2336
# Epoch 26/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9476 - loss: 0.1900 - val_accuracy: 0.9688 - val_loss: 0.2195
# Epoch 27/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9700 - loss: 0.1679 - val_accuracy: 0.9688 - val_loss: 0.2054
# Epoch 28/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9431 - loss: 0.1687 - val_accuracy: 0.9688 - val_loss: 0.1941
# Epoch 29/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9797 - loss: 0.1375 - val_accuracy: 0.9688 - val_loss: 0.1850
# Epoch 30/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9894 - loss: 0.1302 - val_accuracy: 0.9688 - val_loss: 0.1766
# Epoch 31/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9667 - loss: 0.1270 - val_accuracy: 0.9688 - val_loss: 0.1701
# Epoch 32/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9884 - loss: 0.1171 - val_accuracy: 0.9688 - val_loss: 0.1620
# Epoch 33/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9684 - loss: 0.1146 - val_accuracy: 0.9688 - val_loss: 0.1561
# Epoch 34/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9894 - loss: 0.0912 - val_accuracy: 0.9688 - val_loss: 0.1503
# Epoch 35/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9929 - loss: 0.0980 - val_accuracy: 0.9688 - val_loss: 0.1462
# Epoch 36/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9738 - loss: 0.0972 - val_accuracy: 0.9688 - val_loss: 0.1415
# Epoch 37/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9894 - loss: 0.0871 - val_accuracy: 0.9688 - val_loss: 0.1387
# Epoch 38/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0723 - val_accuracy: 0.9688 - val_loss: 0.1370
# Epoch 39/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0816 - val_accuracy: 0.9688 - val_loss: 0.1353
# Epoch 40/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0649 - val_accuracy: 0.9688 - val_loss: 0.1297
# Epoch 41/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0701 - val_accuracy: 0.9688 - val_loss: 0.1263
# Epoch 42/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0640 - val_accuracy: 0.9688 - val_loss: 0.1252
# Epoch 43/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9894 - loss: 0.0539 - val_accuracy: 0.9688 - val_loss: 0.1224
# Epoch 44/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0449 - val_accuracy: 0.9688 - val_loss: 0.1198
# Epoch 45/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0359 - val_accuracy: 0.9688 - val_loss: 0.1171
# Epoch 46/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0568 - val_accuracy: 0.9688 - val_loss: 0.1144
# Epoch 47/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0470 - val_accuracy: 0.9688 - val_loss: 0.1130
# Epoch 48/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0444 - val_accuracy: 0.9688 - val_loss: 0.1132
# Epoch 49/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0409 - val_accuracy: 0.9688 - val_loss: 0.1137
# Epoch 50/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0312 - val_accuracy: 0.9688 - val_loss: 0.1139
# Epoch 51/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0363 - val_accuracy: 0.9688 - val_loss: 0.1070
# Epoch 52/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0322 - val_accuracy: 0.9688 - val_loss: 0.1053
# Epoch 53/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.9688 - val_loss: 0.1048
# Epoch 54/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0293 - val_accuracy: 0.9688 - val_loss: 0.1067
# Epoch 55/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0309 - val_accuracy: 0.9688 - val_loss: 0.1076
# Epoch 56/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0292 - val_accuracy: 0.9688 - val_loss: 0.1055
# Epoch 57/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.9688 - val_loss: 0.1032
# Epoch 58/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.9688 - val_loss: 0.1014
# Epoch 59/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.9688 - val_loss: 0.1015
# Epoch 60/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.9688 - val_loss: 0.1011
# Epoch 61/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 0.9688 - val_loss: 0.1016
# Epoch 62/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.9688 - val_loss: 0.1012
# Epoch 63/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.9688 - val_loss: 0.0996
# Epoch 64/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 0.9688 - val_loss: 0.0959
# Epoch 65/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.9688 - val_loss: 0.0959
# Epoch 66/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0185 - val_accuracy: 0.9688 - val_loss: 0.0973
# Epoch 67/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 0.9688 - val_loss: 0.0968
# Epoch 68/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 0.9688 - val_loss: 0.0966
# Epoch 69/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.9688 - val_loss: 0.0974
# Epoch 70/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.9688 - val_loss: 0.0929
# Epoch 71/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 0.9688 - val_loss: 0.0937
# Epoch 72/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.9688 - val_loss: 0.0925
# Epoch 73/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.9688 - val_loss: 0.0960
# Epoch 74/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9688 - val_loss: 0.0968
# Epoch 75/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.9688 - val_loss: 0.0940
# Epoch 76/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9688 - val_loss: 0.0906
# Epoch 77/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9688 - val_loss: 0.0905
# Epoch 78/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.9688 - val_loss: 0.0927
# Epoch 79/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.9688 - val_loss: 0.0953
# Epoch 80/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.9688 - val_loss: 0.0939
# Epoch 81/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9688 - val_loss: 0.0947
# Epoch 82/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.9688 - val_loss: 0.0950
# Epoch 83/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.9688 - val_loss: 0.0963
# Epoch 84/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.9688 - val_loss: 0.0950
# Epoch 85/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9688 - val_loss: 0.0954
# Epoch 86/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9688 - val_loss: 0.0939
# Epoch 87/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9688 - val_loss: 0.0960
# Epoch 88/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9688 - val_loss: 0.0974
# Epoch 89/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9688 - val_loss: 0.0953
# Epoch 90/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9688 - val_loss: 0.0949
# Epoch 91/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9688 - val_loss: 0.0940
# Epoch 92/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.9688 - val_loss: 0.0902
# Epoch 93/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9688 - val_loss: 0.0902
# Epoch 94/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9688 - val_loss: 0.0912
# Epoch 95/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9688 - val_loss: 0.0934
# Epoch 96/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9688 - val_loss: 0.0932
# Epoch 97/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9688 - val_loss: 0.0952
# Epoch 98/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9688 - val_loss: 0.0926
# Epoch 99/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9688 - val_loss: 0.0946
# Epoch 100/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9688 - val_loss: 0.0967
# Epoch 101/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9688 - val_loss: 0.0957
# Epoch 102/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9688 - val_loss: 0.0955
# Epoch 103/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9688 - val_loss: 0.0944
# Epoch 104/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9688 - val_loss: 0.0946
# Epoch 105/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9688 - val_loss: 0.0939
# Epoch 106/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9688 - val_loss: 0.0927
# Epoch 107/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9688 - val_loss: 0.0929
# Epoch 108/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9688 - val_loss: 0.0923
# Epoch 109/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9688 - val_loss: 0.0942
# Epoch 110/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9688 - val_loss: 0.0952
# Epoch 111/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9688 - val_loss: 0.0939
# Epoch 112/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9688 - val_loss: 0.0933
# Epoch 113/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9688 - val_loss: 0.0954
# Epoch 114/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9688 - val_loss: 0.0980
# Epoch 115/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9688 - val_loss: 0.0969
# Epoch 116/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9688 - val_loss: 0.0962
# Epoch 117/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9688 - val_loss: 0.0944
# Epoch 118/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9688 - val_loss: 0.0946
# Epoch 119/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9688 - val_loss: 0.0934
# Epoch 120/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9688 - val_loss: 0.0932
# Epoch 121/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9688 - val_loss: 0.0937
# Epoch 122/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9688 - val_loss: 0.0941
# Epoch 123/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9688 - val_loss: 0.0954
# Epoch 124/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9688 - val_loss: 0.0930
# Epoch 125/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9688 - val_loss: 0.0938
# Epoch 126/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9688 - val_loss: 0.0914
# Epoch 127/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9688 - val_loss: 0.0930
# Epoch 128/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9688 - val_loss: 0.0928
# Epoch 129/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9688 - val_loss: 0.0934
# Epoch 130/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9688 - val_loss: 0.0937
# Epoch 131/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9688 - val_loss: 0.0946
# Epoch 132/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9688 - val_loss: 0.0954
# Epoch 133/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9688 - val_loss: 0.0949
# Epoch 134/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9688 - val_loss: 0.0943
# Epoch 135/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9688 - val_loss: 0.0948
# Epoch 136/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9688 - val_loss: 0.0943
# Epoch 137/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9688 - val_loss: 0.0928
# Epoch 138/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9688 - val_loss: 0.0925
# Epoch 139/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9688 - val_loss: 0.0932
# Epoch 140/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9688 - val_loss: 0.0941
# Epoch 141/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9688 - val_loss: 0.0941
# Epoch 142/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9688 - val_loss: 0.0949
# Epoch 143/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9688 - val_loss: 0.0952
# Epoch 144/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9688 - val_loss: 0.0973
# Epoch 145/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9688 - val_loss: 0.0960
# Epoch 146/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9688 - val_loss: 0.0949
# Epoch 147/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9688 - val_loss: 0.0948
# Epoch 148/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9688 - val_loss: 0.0956
# Epoch 149/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9688 - val_loss: 0.0971
# Epoch 150/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9688 - val_loss: 0.0989
# Epoch 151/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9688 - val_loss: 0.0984
# Epoch 152/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9688 - val_loss: 0.0987
# Epoch 153/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9688 - val_loss: 0.0962
# Epoch 154/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9688 - val_loss: 0.0940
# Epoch 155/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.0953
# Epoch 156/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9688 - val_loss: 0.0956
# Epoch 157/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9688 - val_loss: 0.0958
# Epoch 158/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9688 - val_loss: 0.0970
# Epoch 159/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9688 - val_loss: 0.0985
# Epoch 160/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.1000
# Epoch 161/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9688 - val_loss: 0.1001
# Epoch 162/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9688 - val_loss: 0.0997
# Epoch 163/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 8.6083e-04 - val_accuracy: 0.9688 - val_loss: 0.0979
# Epoch 164/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9688 - val_loss: 0.0968
# Epoch 165/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9688 - val_loss: 0.0967
# Epoch 166/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.0978
# Epoch 167/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9688 - val_loss: 0.0978
# Epoch 168/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.0961
# Epoch 169/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9688 - val_loss: 0.0965
# Epoch 170/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9688 - val_loss: 0.0969
# Epoch 171/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 8.5795e-04 - val_accuracy: 0.9688 - val_loss: 0.0978
# Epoch 172/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9688 - val_loss: 0.0971
# Epoch 173/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.8035e-04 - val_accuracy: 0.9688 - val_loss: 0.0986
# Epoch 174/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.0979
# Epoch 175/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9688 - val_loss: 0.0980
# Epoch 176/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.6178e-04 - val_accuracy: 0.9688 - val_loss: 0.0978
# Epoch 177/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9688 - val_loss: 0.0973
# Epoch 178/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 7.5446e-04 - val_accuracy: 0.9688 - val_loss: 0.0991
# Epoch 179/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 7.7408e-04 - val_accuracy: 0.9688 - val_loss: 0.0998
# Epoch 180/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9688 - val_loss: 0.0999
# Epoch 181/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.8248e-04 - val_accuracy: 0.9688 - val_loss: 0.1004
# Epoch 182/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.1007
# Epoch 183/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 7.0681e-04 - val_accuracy: 0.9688 - val_loss: 0.0996
# Epoch 184/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.0989
# Epoch 185/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 7.2930e-04 - val_accuracy: 0.9688 - val_loss: 0.0968
# Epoch 186/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 7.7877e-04 - val_accuracy: 0.9688 - val_loss: 0.0958
# Epoch 187/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 7.6511e-04 - val_accuracy: 0.9688 - val_loss: 0.0976
# Epoch 188/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9688 - val_loss: 0.0992
# Epoch 189/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 9.1731e-04 - val_accuracy: 0.9688 - val_loss: 0.1006
# Epoch 190/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.8327e-04 - val_accuracy: 0.9688 - val_loss: 0.1004
# Epoch 191/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 8.5159e-04 - val_accuracy: 0.9688 - val_loss: 0.0992
# Epoch 192/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.0464e-04 - val_accuracy: 0.9688 - val_loss: 0.1001

# %% [markdown]
# # 머신러닝 스케일러와 모델 저장하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv("./data/wine_train.csv")
data
# Out:
#      와인_종류  알코올_도수  사과산_함량  재_함량  재의_알칼리도  마그네슘_함량  총_페놀_함량  플라보노이드_함량  \
# 0        1   13.76    1.53  2.70     19.5      132     2.95       2.74
# 1        2   12.67    0.98  2.24     18.0       99     2.20       1.94
# 2        1   13.58    1.66  2.36     19.1      106     2.86       3.19
# 3        2   13.86    1.51  2.67     25.0       86     2.95       2.86
# 4        1   13.05    2.05  3.22     25.0      124     2.63       2.68
# ..     ...     ...     ...   ...      ...      ...      ...        ...
# 101      2   12.43    1.53  2.29     21.5       86     2.74       3.15
# 102      3   12.20    3.03  2.32     19.0       96     1.25       0.49
# 103      1   13.51    1.80  2.65     19.0      110     2.35       2.53
# 104      2   12.70    3.87  2.40     23.0      101     2.83       2.55
# 105      2   12.51    1.73  1.98     20.5       85     2.20       1.92
#
#      비플라보노이드_페놀_함량  프로안토시아닌_함량  색_강도    색조  희석_와인의_투과율_OD280_OD315  프롤린_함량
# 0             0.50        1.35  5.40  1.25                    3.00    1235
# 1             0.30        1.46  2.62  1.23                    3.16     450
# 2             0.22        1.95  6.90  1.09                    2.88    1515
# 3             0.21        1.87  3.38  1.36                    3.16     410
# 4             0.47        1.92  3.58  1.13                    3.20     830
# ..             ...         ...   ...   ...                     ...     ...
# 101           0.39        1.77  3.94  0.69                    2.84     352
# 102           0.40        0.73  5.50  0.66                    1.83     510
# 103           0.29        1.54  4.20  1.10                    2.87    1095
# 104           0.43        1.95  2.57  1.19                    3.13     463
# 105           0.32        1.48  2.94  1.04                    3.57     672
#
# [106 rows x 14 columns]

# %%
data['와인_종류'].value_counts()
# Out:
# 와인_종류
# 2    42
# 1    35
# 3    29
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   와인_종류                   106 non-null    int64
#  1   알코올_도수                  106 non-null    float64
#  2   사과산_함량                  106 non-null    float64
#  3   재_함량                    106 non-null    float64
#  4   재의_알칼리도                 106 non-null    float64
#  5   마그네슘_함량                 106 non-null    int64
#  6   총_페놀_함량                 106 non-null    float64
#  7   플라보노이드_함량               106 non-null    float64
#  8   비플라보노이드_페놀_함량           106 non-null    float64
#  9   프로안토시아닌_함량              106 non-null    float64
#  10  색_강도                    106 non-null    float64
#  11  색조                      106 non-null    float64
#  12  희석_와인의_투과율_OD280_OD315  106 non-null    float64
#  13  프롤린_함량                  106 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 11.7 KB

# %%
sns.boxplot(data.iloc[:,6:-1])
# Out:
# <Axes: >

# %%
X = data.drop('와인_종류', axis=1)
y = data['와인_종류']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()
X_train_temp = mms.fit_transform(X_train)
X_test_temp = mms.transform(X_test)
mms_X_train = pd.DataFrame(X_train_temp, columns=X_train.columns, index=X_train.index)
mms_X_test = pd.DataFrame(X_test_temp, columns=X_test.columns, index=X_test.index)

# %% [markdown]
# # mms 변수에 있는 MinMaxScaler 가중치 저장
# # joblib
# * joblib.dump(경로, 파일명)
# * joblib.load(경로, 파일명)

# %%
import joblib

# %%
joblib.dump(mms, "./model/MinMax_info2.joblib")
# Out:
# ['./model/MinMax_info2.joblib']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
rfc = RandomForestClassifier(max_depth=3, n_estimators=500, n_jobs=-1, random_state=42)
rfc.fit(mms_X_train, y_train)
pred = rfc.predict(mms_X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        10
#            2       1.00      0.92      0.96        13
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.97        32
#    macro avg       0.97      0.97      0.97        32
# weighted avg       0.97      0.97      0.97        32

# %%
joblib.dump(rfc, "./model/rfc_model.joblib")
# Out:
# ['./model/rfc_model.joblib']
